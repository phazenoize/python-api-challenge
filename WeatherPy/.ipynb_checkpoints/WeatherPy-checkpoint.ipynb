# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 592

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
print(cities)
# Out:
# ['quelimane', 'cafayate', 'papatowai', 'yellowknife', 'waitangi', 'west island', 'polignano a mare', 'bata', 'punta arenas', 'san patricio', 'puerto natales', 'kovalam', "oltinko'l", 'alice springs', 'morondava', 'bethel', 'rabo de peixe', 'kerikeri', 'piti village', 'lompoc', 'albany', 'new norfolk', 'linxia chengguanzhen', 'port alfred', 'port-aux-francais', 'colchani', 'flying fish cove', 'suva', 'moapa valley', 'taiohae', 'invercargill', 'saint-leu', 'ribeira grande', 'yaren', 'touros', 'guerrero negro', 'dunaivtsi', 'iqaluit', 'shenjiamen', 'boca do acre', 'oum hadjer', 'babolsar', 'bang saphan', 'puerto armuelles', 'kodiak', 'khanty-mansiysk', 'atafu village', 'ahau', 'holualoa', 'ponta delgada', 'tazovsky', 'wailua homesteads', 'murzuq', 'impfondo', 'kavaratti', 'darwin', 'wynyard', 'badger', 'kruisfontein', 'vadso', 'aripuana', 'qaqortoq', "karaidel'", 'vila franca do campo', 'carnarvon', 'bloomington', 'progreso', 'grytviken', 'tidjikja', 'dunedin', 'pullman', "st. john's", 'mandalgovi', 'saldanha', 'altay', 'stanley', 'lebu', 'bredasdorp', 'edinburgh of the seven seas', 'taro', 'auki', 'san antonio del estrecho', 'povorino', "nar'yan-mar", 'al mutayrifi', 'tiksi', 'stornoway', 'ascension', 'yulinshi', 'dudinka', 'longyearbyen', 'ponnani', 'gueltat zemmour', 'quellon', 'krasnik', 'soio', 'antigua', 'whitehorse', 'vorgashor', 'ushuaia', 'margaret river', 'nyurba', 'utrik', 'adamstown', 'viqueque', 'altamira', 'petropavlovsk-kamchatsky', 'mwene-ditu', 'albertville', 'olonkinbyen', 'quang ngai', 'isafjordur', 'aqsay', 'shalqar', 'kalmunai', 'bilibino', 'blackmans bay', 'aykhal', 'udachny', 'tralee', 'hasaki', 'teluknaga', 'fort bragg', 'georgetown', 'truro', 'recreo', 'gangtok', 'igarka', 'shache', 'kingston', 'spring creek', 'kulhudhuffushi', 'puerto leguizamo', 'wanxian', "'ohonua", 'byron bay', 'thompson', 'port sudan', 'anse royale', 'mananjary', 'hermanus', 'acapulco de juarez', 'kharan', 'pagsanghan', 'mamou', 'ippy', 'ares', 'torghay', 'hammerfest', 'turpan', 'namibe', 'bikenibeu village', 'ilulissat', 'hawaiian paradise park', 'hihifo', 'mangrol', 'alto barinas', 'yeppoon', 'albertina', 'palikir - national government center', 'dakar', 'la trinitaria', 'talnakh', 'grants', 'sept-iles', 'sirjan', 'nuuk', 'chonchi', 'borba', 'chapadinha', 'la passe', 'guatire', 'puerto ayora', 'avarua', 'fortuna', 'saudarkrokur', 'wewak', 'ribadavia', 'zhangjiakou', 'morehead city', 'rongelap', 'mirny', 'viersen', 'sao joao da barra', 'castillos', 'pathalgaon', 'qusmuryn', 'nieuw amsterdam', 'marsa alam', 'constantia', 'nemuro', 'knokke-heist', 'port elizabeth', 'bin yauri', 'linda', 'jamestown', 'east london', 'afaahiti', 'kodinar', 'platteville', 'espargos', 'pago pago', 'mejit', 'port mathurin', 'sitia', 'qujing', 'montmagny', 'vilyuysk', 'djamaa', 'severo-yeniseyskiy', 'chivolo', 'boujniba', 'tinana', 'nogliki', 'taitung city', 'pizarro', 'abepura', 'kosong', 'stahnsdorf', 'yanchep', 'newman', 'vilyuchinsk', 'atar', 'sitka', 'ca mau', 'vingt cinq', 'crane', 'molsheim', 'nizhneangarsk', 'mount pearl', 'plouzane', 'aginskoye', 'hamilton', 'pudozh', 'aasiaat', 'taulaga', 'geraldton', 'klyuchi', 'alakurtti', 'durban', 'praia da vitoria', 'margate', 'enewetak', 'naze', 'opuwo', 'fuvahmulah', 'long beach', 'nova sintra', 'wa', 'at-bashi', "ust'-kut", 'kapuskasing', 'dinghaicun', 'flin flon', 'waingapu', 'timbuktu', 'malinao ilaya', 'tegueste', "kem'", 'caleta de carquin', 'inekar', 'erdenet', 'sandnessjoen', 'chongwe', 'tanjung selor', 'san luis de la loma', 'remire-montjoly', 'nema', 'tommot', 'urzhum', 'karratha', 'anadyr', 'talcahuano', 'portland', 'waspan', 'cativa', 'tongren', 'haiku-pauwela', 'ishqoshim', 'belmonte', 'kone', 'tura', 'chibougamau', 'westport', 'shasta lake', 'dakhla', 'larache', 'college', 'keflavik', 'tabou', 'el calafate', 'princeville', 'dabhol', 'saipan', 'ixtapa', 'tobelo', 'iskateley', 'tieli', 'namsos', 'murghob', 'minas de marcona', 'hithadhoo', 'shimoda', 'alesund', 'bathsheba', 'forbesganj', 'kuta', 'lu ...

# %%
# Set the API base URL
url = 'https://api.openweathermap.org/data/2.5/weather?'
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
 
# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&units=metric&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | quelimane
# Processing Record 2 of Set 1 | cafayate
# Processing Record 3 of Set 1 | papatowai
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | waitangi
# Processing Record 6 of Set 1 | west island
# Processing Record 7 of Set 1 | polignano a mare
# Processing Record 8 of Set 1 | bata
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | san patricio
# Processing Record 11 of Set 1 | puerto natales
# Processing Record 12 of Set 1 | kovalam
# Processing Record 13 of Set 1 | oltinko'l
# Processing Record 14 of Set 1 | alice springs
# Processing Record 15 of Set 1 | morondava
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | rabo de peixe
# Processing Record 18 of Set 1 | kerikeri
# Processing Record 19 of Set 1 | piti village
# Processing Record 20 of Set 1 | lompoc
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | linxia chengguanzhen
# Processing Record 18 of Set 4 | borba
# Processing Record 19 of Set 4 | chapadinha
# Processing Record 20 of Set 4 | la passe
# Processing Record 21 of Set 4 | guatire
# Processing Record 22 of Set 4 | puerto ayora
# Processing Record 23 of Set 4 | avarua
# Processing Record 24 of Set 4 | fortuna
# Processing Record 25 of Set 4 | saudarkrokur
# Processing Record 26 of Set 4 | wewak
# Processing Record 27 of Set 4 | ribadavia
# Processing Record 28 of Set 4 | zhangjiakou
# City not found. Skipping...
# Processing Record 29 of Set 4 | morehead city
# City not found. Skipping...
# Processing Record 30 of Set 4 | rongelap
# Processing Record 31 of Set 4 | mirny
# Processing Record 32 of Set 4 | viersen
# Processing Record 33 of Set 4 | sao joao da barra
# Processing Record 34 of Set 4 | castillos
# Processing Record 35 of Set 4 | pathalgaon
# Processing Record 36 of Set 4 | qusmuryn
# Processing Record 37 of Set 4 | nieuw amsterdam
# Processing Record 38 of Set 4 | marsa alam
# Processing Record 39 of Set 4 | constantia
# Processing Record 40 of Set 4 | nemuro
# Processing Record 41 of Set 4 | knokke-heist
# Processing Record 42 of Set 4 | port elizabeth
# Processing Record 43 of Set 4 | bin yauri
# Processing Record 44 of Set 4 | linda
# Processing Record 45 of Set 4 | jamestown
# Processing Record 46 of Set 4 | east london
# Processing Record 47 of Set 4 | afaahiti
# Processing Record 48 of Set 4 | kodinar
# Processing Record 49 of Set 4 | platteville
# Processing Record 0 of Set 5 | espargos
# City not found. Skipping...
# Processing Record 1 of Set 5 | pago pago
# Processing Record 2 of Set 5 | mejit
# Processing Record 3 of Set 5 | port mathurin
# Processing Record 4 of Set 5 | sitia
# Processing Record 5 of Set 5 | qujing
# Processing Record 6 of Set 5 | montmagny
# Processing Record 7 of Set 5 | vilyuysk
# Processing Record 8 of Set 5 | djamaa
# Processing Record 9 of Set 5 | severo-yeniseyskiy
# Processing Record 10 of Set 5 | chivolo
# Processing Record 11 of Set 5 | boujniba
# Processing Record 12 of Set 5 | tinana
# City not found. Skipping...
# Processing Record 13 of Set 5 | nogliki
# Processing Record 14 of Set 5 | taitung city
# Processing Record 15 of Set 5 | pizarro
# Processing Record 16 of Set 5 | abepura
# Processing Record 17 of Set 5 | kosong
# Processing Record 18 of Set 5 | stahnsdorf
# Processing Record 19 of Set 5 | yanchep
# Processing Record 20 of Set 5 | newman
# Processing Record 21 of Set 5 | vilyuchinsk
# Processing Record 22 of Set 5 | atar
# Processing Record 23 of Set 5 | sitka
# Processing Record 24 of Set 5 | ca mau
# Processing Record 25 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 26 of Set 5 | crane
# Processing Record 27 of Set 5 | molsheim
# Processing Record 28 of Set 5 | nizhneangarsk
# Processing Record 29 of Set 5 | mount pearl
# Processing Record 30 of Set 5 | plouzane
# Processing Record 31 of Set 5 | aginskoye
# Processing Record 32 of Set 5 | hamilton
# Processing Record 33 of Set 5 | pudozh
# Processing Record 34 of Set 5 | aasiaat
# Processing Record 35 of Set 5 | taulaga
# Processing Record 36 of Set 5 | geraldton
# Processing Record 37 of Set 5 | klyuchi
# Processing Record 38 of Set 5 | alakurtti
# Processing Record 39 of Set 5 | durban
# Processing Record 40 of Set 5 | praia da vitoria
# Processing Record 41 of Set 5 | margate
# Processing Record 42 of Set 5 | enewetak
# Processing Record 43 of Set 5 | naze
# Processing Record 44 of Set 5 | opuwo
# Processing Record 45 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 46 of Set 5 | long beach
# Processing Record 47 of Set 5 | nova sintra
# Processing Record 48 of Set 5 | wa
# City not found. Skipping...
# Processing Record 49 of Set 5 | at-bashi
# Processing Record 0 of Set 6 | ust'-kut
# Processing Record 1 of Set 6 | kapuskasing
# Processing Record 2 of Set 6 | dinghaicun
# Processing Record 3 of Set 6 | flin flon
# Processing Record 4 of Set 6 | waingapu
# Processing Record 5 of Set 6 | timbuktu
# Processing Record 6 of Set 6 | malinao ilaya
# Processing Record 7 of Set 6 | tegueste
# Processing Record 8 of Set 6 | kem'
# Processing Record 9 of Set 6 | caleta de carquin
# Processing Record 10 of Set 6 | inekar
# City not found. Skipping...
# Processing Record 11 of Set 6 | erdenet
# Processing Record 12 of Set 6 | sandnessjoen
# Processing Record 13 of Set 6 | chongwe
# Processing Record 14 of Set 6 | tanjung selor
# City not found. Skipping...
# Processing Record 15 of Set 6 | san luis de la loma
# Processing Record 16 of Set 6 | remire-montjoly
# Processing Record 17 of Set 6 | nema
# Processing Record 18 of Set 6 | tommot
# Processing Record 19 of Set 6 | urzhum
# Processing Record 20 of Set 6 | karratha
# Processing Record 21 of Set 6 | anadyr
# Processing Record 22 of Set 6 | talcahuano
# Processing Record 23 of Set 6 | portland
# Processing Record 24 of Set 6 | waspan
# Processing Record 25 of Set 6 | cativa
# Processing Record 26 of Set 6 | tongren
# Processing Record 27 of Set 6 | haiku-pauwela
# Processing Record 28 of Set 6 | ishqoshim
# Processing Record 29 of Set 6 | belmonte
# Processing Record 30 of Set 6 | kone
# Processing Record 31 of Set 6 | tura
# Processing Record 32 of Set 6 | chibougamau
# Processing Record 33 of Set 6 | westport
# Processing Record 34 of Set 6 | shasta lake
# Processing Record 35 of Set 6 | dakhla
# Processing Record 36 of Set 6 | larache
# Processing Record 37 of Set 6 | college
# Processing Record 38 of Set 6 | keflavik
# Processing Record 39 of Set 6 | tabou
# Processing Record 40 of Set 6 | el calafate
# Processing Record 41 of Set 6 | princeville
# Processing Record 42 of Set 6 | dabhol
# Processing Record 43 of Set 6 | saipan
# Processing Record 44 of Set 6 | ixtapa
# Processing Record 45 of Set 6 | tobelo
# Processing Record 46 of Set 6 | iskateley
# Processing Record 47 of Set 6 | tieli
# Processing Record 48 of Set 6 | namsos
# Processing Record 49 of Set 6 | murghob
# Processing Record 0 of Set 7 | minas de marcona
# Processing Record 1 of Set 7 | hithadhoo
# Processing Record 2 of Set 7 | shimoda
# Processing Record 3 of Set 7 | alesund
# Processing Record 4 of Set 7 | bathsheba
# Processing Record 5 of Set 7 | forbesganj
# Processing Record 6 of Set 7 | kuta
# Processing Record 7 of Set 7 | lubao
# Processing Record 8 of Set 7 | cabo san lucas
# Processing Record 9 of Set 7 | ust-nera
# Processing Record 10 of Set 7 | nova vicosa
# Processing Record 11 of Set 7 | mlimba
# Processing Record 12 of Set 7 | la ronge
# Processing Record 35 of Set 8 | mount isa
# Processing Record 36 of Set 8 | luderitz
# Processing Record 37 of Set 8 | punata
# Processing Record 38 of Set 8 | happy valley-goose bay
# Processing Record 39 of Set 8 | tromso
# Processing Record 40 of Set 8 | al fqih ben calah
# Processing Record 41 of Set 8 | bel ombre
# Processing Record 42 of Set 8 | arraial do cabo
# Processing Record 43 of Set 8 | zboriv
# Processing Record 44 of Set 8 | puerto ayacucho
# Processing Record 45 of Set 8 | pisco
# Processing Record 46 of Set 8 | corowa
# Processing Record 47 of Set 8 | la'ie
# Processing Record 48 of Set 8 | arkhangel'sk
# Processing Record 49 of Set 8 | roma
# Processing Record 0 of Set 9 | hadibu
# Processing Record 1 of Set 9 | simanggang
# Processing Record 2 of Set 9 | shimanovsk
# Processing Record 3 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 4 of Set 9 | salalah
# Processing Record 5 of Set 9 | nurota
# Processing Record 6 of Set 9 | nashik
# Processing Record 7 of Set 9 | olinda
# Processing Record 8 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 9 | gradiska
# Processing Record 10 of Set 9 | kodinsk
# Processing Record 11 of Set 9 | deqen
# Processing Record 12 of Set 9 | merizo village
# Processing Record 13 of Set 9 | road town
# Processing Record 14 of Set 9 | qui nhon
# Processing Record 15 of Set 9 | pauini
# Processing Record 16 of Set 9 | new romney
# Processing Record 17 of Set 9 | vila velha
# Processing Record 18 of Set 9 | ubari
# Processing Record 19 of Set 9 | villa huidobro
# Processing Record 20 of Set 9 | jand
# Processing Record 21 of Set 9 | basse-terre
# Processing Record 22 of Set 9 | youssoufia
# Processing Record 23 of Set 9 | belozersk
# Processing Record 24 of Set 9 | mil'kovo
# Processing Record 25 of Set 9 | zahedan
# Processing Record 26 of Set 9 | eureka
# Processing Record 27 of Set 9 | kayangel
# Processing Record 28 of Set 9 | piui
# Processing Record 29 of Set 9 | gadzhiyevo
# Processing Record 30 of Set 9 | puerto carreno
# Processing Record 31 of Set 9 | armyansk
# Processing Record 32 of Set 9 | colac
# Processing Record 33 of Set 9 | macau
# Processing Record 34 of Set 9 | baluntaicun
# City not found. Skipping...
# Processing Record 35 of Set 9 | embi
# Processing Record 36 of Set 9 | suncho corral
# Processing Record 37 of Set 9 | lospalos
# Processing Record 38 of Set 9 | pusad
# Processing Record 39 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 40 of Set 9 | kiama
# Processing Record 41 of Set 9 | san antonio de pale
# Processing Record 42 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 43 of Set 9 | nekrasovskoye
# Processing Record 44 of Set 9 | uturoa
# Processing Record 45 of Set 9 | santa cruz del norte
# Processing Record 46 of Set 9 | moab
# Processing Record 47 of Set 9 | lihue
# Processing Record 48 of Set 9 | gomez farias
# Processing Record 49 of Set 9 | suoyarvi
# Processing Record 0 of Set 10 | las palmas de gran canaria
# Processing Record 1 of Set 10 | kharkhorin
# Processing Record 2 of Set 10 | oranjemund
# Processing Record 3 of Set 10 | juan griego
# Processing Record 4 of Set 10 | yen vinh
# Processing Record 5 of Set 10 | tolanaro
# Processing Record 6 of Set 10 | suvorovskaya
# Processing Record 7 of Set 10 | francistown
# Processing Record 8 of Set 10 | askoy
# Processing Record 9 of Set 10 | mpika
# Processing Record 10 of Set 10 | fort william
# Processing Record 11 of Set 10 | nouadhibou
# Processing Record 12 of Set 10 | jayapura
# Processing Record 13 of Set 10 | huanggang
# Processing Record 14 of Set 10 | kimbe
# Processing Record 15 of Set 10 | male
# Processing Record 16 of Set 10 | taksimo
# Processing Record 17 of Set 10 | kargasok
# Processing Record 18 of Set 10 | shivpuri
# Processing Record 19 of Set 10 | kuraymah
# Processing Record 20 of Set 10 | selfoss
# Processing Record 21 of Set 10 | arkalyk
# Processing Record 22 of Set 10 | machico
# Processing Record 23 of Set 10 | mount darwin
# Processing Record 24 of Set 10 | labuan
# Processing Record 25 of Set 10 | igrim
# Processing Record 26 of Set 10 | fort st. john
# Processing Record 27 of Set 10 | prineville
# Processing Record 28 of Set 10 | lata
# Processing Record 29 of Set 10 | thinadhoo
# Processing Record 30 of Set 10 | dwarka
# Processing Record 31 of Set 10 | twon-brass
# Processing Record 32 of Set 10 | rawson
# Processing Record 33 of Set 10 | waghai
# Processing Record 34 of Set 10 | tibati
# Processing Record 35 of Set 10 | puerto baquerizo moreno
# Processing Record 36 of Set 10 | javanrud
# Processing Record 37 of Set 10 | borgarnes
# Processing Record 38 of Set 10 | cabedelo
# Processing Record 39 of Set 10 | mastic beach
# Processing Record 40 of Set 10 | buckhannon
# Processing Record 41 of Set 10 | poronaysk
# Processing Record 42 of Set 10 | yamoto
# Processing Record 43 of Set 10 | murwara
# Processing Record 44 of Set 10 | bonthe
# Processing Record 45 of Set 10 | dongola
# Processing Record 46 of Set 10 | arilje
# Processing Record 47 of Set 10 | al-`ula
# City not found. Skipping...
# Processing Record 48 of Set 10 | san pedro pochutla
# Processing Record 49 of Set 10 | erenhot
# Processing Record 0 of Set 11 | zaragoza
# Processing Record 1 of Set 11 | tsiombe
# Processing Record 2 of Set 11 | dryden
# Processing Record 3 of Set 11 | baiyin
# Processing Record 4 of Set 11 | harrisonville
# Processing Record 5 of Set 11 | nicoya
# Processing Record 6 of Set 11 | la foa
# Processing Record 7 of Set 11 | turkestan
# Processing Record 8 of Set 11 | togur
# Processing Record 9 of Set 11 | contamana
# Processing Record 10 of Set 11 | chipinge
# Processing Record 11 of Set 11 | viljoenskroon
# Processing Record 12 of Set 11 | nizhniy odes
# Processing Record 13 of Set 11 | zaozersk
# Processing Record 14 of Set 11 | yarmouth
# Processing Record 15 of Set 11 | costa calma
# City not found. Skipping...
# Processing Record 16 of Set 11 | dabakala
# Processing Record 17 of Set 11 | sao joao do piaui
# Processing Record 18 of Set 11 | hassi messaoud
# Processing Record 19 of Set 11 | monticello
# Processing Record 20 of Set 11 | mata-utu
# Processing Record 21 of Set 11 | viedma
# Processing Record 22 of Set 11 | novyy urengoy
# Processing Record 23 of Set 11 | rio grande
# Processing Record 24 of Set 11 | genhe
# Processing Record 25 of Set 11 | kazanskoye
# Processing Record 26 of Set 11 | kourou
# Processing Record 27 of Set 11 | islamkot
# Processing Record 28 of Set 11 | port blair
# Processing Record 29 of Set 11 | southampton
# Processing Record 30 of Set 11 | mossel bay
# Processing Record 31 of Set 11 | ouadda
# Processing Record 32 of Set 11 | camocim
# Processing Record 33 of Set 11 | nuevo ideal
# Processing Record 34 of Set 11 | mabaruma
# Processing Record 35 of Set 11 | bodaybo
# Processing Record 36 of Set 11 | brisas de zicatela
# Processing Record 37 of Set 11 | yilan
# Processing Record 38 of Set 11 | sainte-anne-des-monts
# Processing Record 39 of Set 11 | 'ibri
# City not found. Skipping...
# Processing Record 40 of Set 11 | pasni
# Processing Record 41 of Set 11 | upata
# Processing Record 42 of Set 11 | l'govskiy
# Processing Record 43 of Set 11 | jertih
# Processing Record 44 of Set 11 | dosso
# Processing Record 45 of Set 11 | nabire
# Processing Record 46 of Set 11 | lagos
# Processing Record 47 of Set 11 | alice
# Processing Record 48 of Set 11 | bafra
# Processing Record 49 of Set 11 | lander
# Processing Record 0 of Set 12 | cockburn town
# Processing Record 1 of Set 12 | cidreira
# Processing Record 2 of Set 12 | orchard homes
# Processing Record 3 of Set 12 | mugia
# Processing Record 4 of Set 12 | kununurra
# Processing Record 5 of Set 12 | wuwei
# Processing Record 6 of Set 12 | dundaga
# Processing Record 7 of Set 12 | puerto aysen
# Processing Record 8 of Set 12 | mazagao
# Processing Record 9 of Set 12 | zuunmod
# Processing Record 10 of Set 12 | kerouane
# Processing Record 11 of Set 12 | seogwipo
# City not found. Skipping...
# Processing Record 12 of Set 12 | nizhniy ingash
# Processing Record 13 of Set 12 | san sebastian de la gomera
# Processing Record 14 of Set 12 | villa de arista
# Processing Record 15 of Set 12 | isiolo
# Processing Record 16 of Set 12 | krasnyy kut
# Processing Record 17 of Set 12 | aktobe
# Processing Record 18 of Set 12 | port douglas
# Processing Record 19 of Set 12 | sao tome
# Processing Record 20 of Set 12 | phan thiet
# Processing Record 21 of Set 12 | maba
# Processing Record 22 of Set 12 | tutoia
# Processing Record 23 of Set 12 | cable beach
# City not found. Skipping...
# Processing Record 24 of Set 12 | bardai
# Processing Record 25 of Set 12 | skelleftea
# Processing Record 26 of Set 12 | alta
# Processing Record 27 of Set 12 | velikiy novgorod
# Processing Record 28 of Set 12 | lib
# Processing Record 29 of Set 12 | at taj
# Processing Record 30 of Set 12 | nanao
# Processing Record 31 of Set 12 | uray
# Processing Record 32 of Set 12 | ancud
# Processing Record 33 of Set 12 | iwanai
# Processing Record 34 of Set 12 | mahabe
# City not found. Skipping...
# Processing Record 35 of Set 12 | huyuk
# Processing Record 36 of Set 12 | tsumeb
# Processing Record 37 of Set 12 | urangan
# Processing Record 38 of Set 12 | yatagan
# Processing Record 39 of Set 12 | mocajuba
# Processing Record 40 of Set 12 | antofagasta
# Processing Record 41 of Set 12 | mansalay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    quelimane -17.8786   36.8883     25.93        78           0        3.47
# 1     cafayate -26.0730  -65.9761     22.86        61          71        5.77
# 2    papatowai -46.5619  169.4708      9.58        95          67        1.99
# 3  yellowknife  62.4560 -114.3525     -3.66        88         100        6.71
# 4     waitangi -43.9535 -176.5597     12.68        90         100        4.92
#
#   Country        Date
# 0      MZ  1698172070
# 1      AR  1698172070
# 2      NZ  1698172070
# 3      CA  1698171803
# 4      NZ  1698172071

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          quelimane -17.8786   36.8883     25.93        78           0
# 1           cafayate -26.0730  -65.9761     22.86        61          71
# 2          papatowai -46.5619  169.4708      9.58        95          67
# 3        yellowknife  62.4560 -114.3525     -3.66        88         100
# 4           waitangi -43.9535 -176.5597     12.68        90         100
#
#          Wind Speed Country        Date
# City_ID
# 0              3.47      MZ  1698172070
# 1              5.77      AR  1698172070
# 2              1.99      NZ  1698172070
# 3              6.71      CA  1698171803
# 4              4.92      NZ  1698172071

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(C)')
plt.title('City Latitude vs.Temperature(2023-10-24)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title('City Latitude vs.Humidity(2023-10-24)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('City Latitude vs.Cloudiness(2023-10-24)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
plt.title('City Latitude vs.Wind Speed(2023-10-24)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_reg(x_axis, y_axis,eq_loc):  
    correlation = st.pearsonr(x_axis,y_axis)
    p_slope, p_int, p_r, p_p, p_std_err = st.linregress(x_axis, y_axis)
    p_fit = p_slope * x_axis + p_int
    eq= f"y ={p_slope: .2f}x +{ p_int: .2f}"
       
    #Plot the line
    plt.scatter(x_axis, y_axis ,marker="o")
    plt.plot(x_axis,p_fit,"--", color='red')
    plt.annotate(eq, eq_loc, fontsize=12, color='red')
    print(f"The r-value between {x_axis.name} and {y_axis.name} is {round(correlation[0],2)}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3             yellowknife  62.4560 -114.3525     -3.66        88         100
# 6        polignano a mare  40.9959   17.2159     23.16        80          97
# 7                    bata   1.8639    9.7658     24.92       100          75
# 9            san patricio  28.0170  -97.5169     31.92        56          46
# 11                kovalam   8.3667   76.9967     28.05        89          40
#
#          Wind Speed Country        Date
# City_ID
# 3              6.71      CA  1698171803
# 6              4.73      IT  1698172071
# 7              2.06      GQ  1698172071
# 9             10.04      US  1698172072
# 11             1.03      IN  1698172072

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          quelimane -17.8786   36.8883     25.93        78           0
# 1           cafayate -26.0730  -65.9761     22.86        61          71
# 2          papatowai -46.5619  169.4708      9.58        95          67
# 4           waitangi -43.9535 -176.5597     12.68        90         100
# 5        west island -12.1568   96.8225     25.99        83          40
#
#          Wind Speed Country        Date
# City_ID
# 0              3.47      MZ  1698172070
# 1              5.77      AR  1698172070
# 2              1.99      NZ  1698172070
# 4              4.92      NZ  1698172071
# 5              5.14      CC  1698172071

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'],(10, -10))
plt.xlabel('Latitude')
plt.ylabel('Temperature(C)')
# Out:
# The r-value between Lat and Max Temp is -0.89
# Text(0, 0.5, 'Temperature(C)')

# %%
# Linear regression on Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'],(-30, 5))
plt.xlabel('Latitude')
plt.ylabel('Temperature(C)')
# Out:
# The r-value between Lat and Max Temp is 0.81
# Text(0, 0.5, 'Temperature(C)')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Humidity'],(55, 10))
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
# Out:
# The r-value between Lat and Humidity is 0.17
# Text(0, 0.5, 'Humidity(%)')

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Humidity'],(-50, 25))
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
# Out:
# The r-value between Lat and Humidity is -0.01
# Text(0, 0.5, 'Humidity(%)')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'],(50, 50))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
# Out:
# The r-value between Lat and Cloudiness is 0.07
# Text(0, 0.5, 'Cloudiness(%)')

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'],(-50, 65))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
# Out:
# The r-value between Lat and Cloudiness is 0.18
# Text(0, 0.5, 'Cloudiness(%)')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'],(10, 12))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
# Out:
# The r-value between Lat and Wind Speed is 0.04
# Text(0, 0.5, 'Wind Speed(m/s)')

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'],(-50, 9))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
# Out:
# The r-value between Lat and Wind Speed is -0.39
# Text(0, 0.5, 'Wind Speed(m/s)')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
