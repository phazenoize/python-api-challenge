# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# !pip install cartopy geoviews
# Out:
# Collecting cartopy
#   Downloading Cartopy-0.22.0-cp310-cp310-win_amd64.whl (11.2 MB)
#      ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#       --------------------------------------- 0.2/11.2 MB 6.4 MB/s eta 0:00:02
#      --- ------------------------------------ 1.1/11.2 MB 13.7 MB/s eta 0:00:01
#      -------- ------------------------------- 2.4/11.2 MB 19.3 MB/s eta 0:00:01
#      --------------- ------------------------ 4.3/11.2 MB 25.1 MB/s eta 0:00:01
#      ---------------------- ----------------- 6.2/11.2 MB 28.3 MB/s eta 0:00:01
#      -------------------------- ------------- 7.5/11.2 MB 28.2 MB/s eta 0:00:01
#      --------------------------------- ------ 9.4/11.2 MB 30.0 MB/s eta 0:00:01
#      --------------------------------------  11.2/11.2 MB 36.3 MB/s eta 0:00:01
#      --------------------------------------- 11.2/11.2 MB 32.7 MB/s eta 0:00:00
# Collecting geoviews
#   Downloading geoviews-1.10.1-py2.py3-none-any.whl (509 kB)
#      ---------------------------------------- 0.0/509.8 kB ? eta -:--:--
#      ---------------------------------------- 509.8/509.8 kB ? eta 0:00:00
# Requirement already satisfied: matplotlib>=3.4 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from cartopy) (3.7.1)
# Requirement already satisfied: numpy>=1.21 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from cartopy) (1.24.3)
# Requirement already satisfied: shapely>=1.7 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from cartopy) (2.0.2)
# Collecting pyshp>=2.1
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 0.0/46.5 kB ? eta -:--:--
#      ---------------------------------------- 46.5/46.5 kB ? eta 0:00:00
# Requirement already satisfied: packaging>=20 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from cartopy) (23.0)
# Requirement already satisfied: pyproj>=3.1.0 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from cartopy) (3.6.1)
# Requirement already satisfied: param in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from geoviews) (1.13.0)
# Collecting xyzservices
#   Downloading xyzservices-2023.10.0-py3-none-any.whl (57 kB)
#      ---------------------------------------- 0.0/57.2 kB ? eta -:--:--
#      ---------------------------------------- 57.2/57.2 kB ? eta 0:00:00
# Collecting panel>=1.0.0
#   Downloading panel-1.3.0-py2.py3-none-any.whl (20.4 MB)
#      ---------------------------------------- 0.0/20.4 MB ? eta -:--:--
#      --- ------------------------------------ 1.7/20.4 MB 53.8 MB/s eta 0:00:01
#      ------ --------------------------------- 3.4/20.4 MB 43.6 MB/s eta 0:00:01
#      ---------- ----------------------------- 5.4/20.4 MB 38.6 MB/s eta 0:00:01
#      -------------- ------------------------- 7.2/20.4 MB 38.2 MB/s eta 0:00:01
#      ----------------- ---------------------- 9.2/20.4 MB 39.1 MB/s eta 0:00:01
#      -------------------- ------------------ 10.9/20.4 MB 40.9 MB/s eta 0:00:01
#      ------------------------ -------------- 12.9/20.4 MB 38.5 MB/s eta 0:00:01
#      --------------------------- ----------- 14.4/20.4 MB 40.9 MB/s eta 0:00:01
#      ------------------------------ -------- 16.2/20.4 MB 40.9 MB/s eta 0:00:01
#      ---------------------------------- ---- 18.2/20.4 MB 38.6 MB/s eta 0:00:01
#      --------------------------------------  19.9/20.4 MB 38.6 MB/s eta 0:00:01
#      --------------------------------------  20.4/20.4 MB 38.6 MB/s eta 0:00:01
#      --------------------------------------  20.4/20.4 MB 38.6 MB/s eta 0:00:01
#      --------------------------------------- 20.4/20.4 MB 28.5 MB/s eta 0:00:00
# Collecting bokeh<3.3.0,>=3.1.0
#   Downloading bokeh-3.2.2-py3-none-any.whl (7.8 MB)
#      ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#      ------- -------------------------------- 1.5/7.8 MB 30.7 MB/s eta 0:00:01
#      --------------- ------------------------ 3.0/7.8 MB 38.6 MB/s eta 0:00:01
#      ---------------------- ----------------- 4.4/7.8 MB 35.1 MB/s eta 0:00:01
#      -------------------------------- ------- 6.3/7.8 MB 33.8 MB/s eta 0:00:01
#      ---------------------------------------  7.8/7.8 MB 35.7 MB/s eta 0:00:01
#      ---------------------------------------- 7.8/7.8 MB 31.3 MB/s eta 0:00:00
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from geoviews) (1.16.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (3.1.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (6.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (1.5.3)
# Requirement already satisfied: contourpy>=1 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (1.0.5)
# Requirement already satisfied: tornado>=5.1 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (6.2)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from holoviews>=1.16.0->geoviews) (2.3.0)
# Requirement already satisfied: colorcet in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (1.4.4)
# Collecting markdown-it-py
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#      ---------------------------------------- 87.5/87.5 kB ? eta 0:00:00
# Collecting param
#   Downloading param-2.0.0-py3-none-any.whl (116 kB)
#      ---------------------------------------- 0.0/116.8 kB ? eta -:--:--
#      ---------------------------------------- 116.8/116.8 kB ? eta 0:00:00
# Collecting mdit-py-plugins
#   Downloading mdit_py_plugins-0.4.0-py3-none-any.whl (54 kB)
#      ---------------------------------------- 0.0/54.1 kB ? eta -:--:--
#      ---------------------------------------- 54.1/54.1 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (2.29.0)
# Requirement already satisfied: bleach in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (4.65.0)
# Requirement already satisfied: typing-extensions in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (4.5.0)
# Requirement already satisfied: markdown in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (3.4.1)
# Collecting linkify-it-py
#   Downloading linkify_it_py-2.0.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: certifi in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from pyproj>=3.1.0->cartopy) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from Jinja2>=2.9->bokeh<3.3.0,>=3.1.0->geoviews) (2.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from pandas>=1.2->bokeh<3.3.0,>=3.1.0->geoviews) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.4->cartopy) (1.16.0)
# Requirement already satisfied: colorama in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from tqdm>=4.48.0->panel>=1.0.0->geoviews) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from colorcet->holoviews>=1.16.0->geoviews) (0.5.0)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.2-py3-none-any.whl (6.2 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\patri\anaconda3\envs\dev\lib\site-packages (from requests->panel>=1.0.0->geoviews) (1.26.15)
# Installing collected packages: xyzservices, uc-micro-py, pyshp, param, mdurl, markdown-it-py, linkify-it-py, mdit-py-plugins, cartopy, bokeh, panel, geoviews
#   Attempting uninstall: param
#     Found existing installation: param 1.13.0
#     Uninstalling param-1.13.0:
#       Successfully uninstalled param-1.13.0
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 2.4.3
#     Uninstalling bokeh-2.4.3:
#       Successfully uninstalled bokeh-2.4.3
#   Attempting uninstall: panel
#     Found existing installation: panel 0.14.3
#     Uninstalling panel-0.14.3:
#       Successfully uninstalled panel-0.14.3
# Successfully installed bokeh-3.2.2 cartopy-0.22.0 geoviews-1.10.1 linkify-it-py-2.0.2 markdown-it-py-3.0.0 mdit-py-plugins-0.4.0 mdurl-0.1.2 panel-1.3.0 param-2.0.0 pyshp-2.3.1 uc-micro-py-1.0.2 xyzservices-2023.10.0

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json
import cartopy
import geoviews as gv

import warnings
warnings.filterwarnings("ignore")

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0    quelimane -17.8786   36.8883     25.93        78           0
# 1        1     cafayate -26.0730  -65.9761     22.86        61          71
# 2        2    papatowai -46.5619  169.4708      9.58        95          67
# 3        3  yellowknife  62.4560 -114.3525     -3.66        88         100
# 4        4     waitangi -43.9535 -176.5597     12.68        90         100
#
#    Wind Speed Country        Date
# 0        3.47      MZ  1698172070
# 1        5.77      AR  1698172070
# 2        1.99      NZ  1698172070
# 3        6.71      CA  1698171803
# 4        4.92      NZ  1698172071

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
all_city_map = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    alpha = 0.5,
    color = 'Country'
)

# Display the map
all_city_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Country,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_temp0 = city_data_df.loc[city_data_df['Max Temp']<30,:]
city_temp = city_temp0.loc[city_temp0['Max Temp']>21,:]
city_wind = city_temp.loc[city_temp['Wind Speed']<3,:]
city_cloud = city_wind.loc[city_wind['Cloudiness']==0,:]
city_cloud
# Drop any rows with null values
city_ideal = city_cloud.dropna()
# Display sample data
city_ideal
# Out:
#      City_ID                        City      Lat       Lng  Max Temp  \
# 49        49           wailua homesteads  22.0669 -159.3780     26.24
# 132      132                  port sudan  19.6175   37.2164     29.41
# 186      186                       linda  39.1277 -121.5508     22.88
# 195      195                       sitia  35.2000   26.0986     22.77
# 328      328                   knoxville  35.9606  -83.9207     24.61
# 354      354                      waddan  29.1614   16.1390     29.47
# 357      357                    upington -28.4478   21.2561     25.21
# 400      400                        jand  33.4299   72.0193     23.49
# 424      424                       lihue  21.9789 -159.3672     26.58
# 486      486                    chipinge -20.1883   32.6236     23.31
# 508      508                 nuevo ideal  24.8875 -105.0728     21.41
# 536      536  san sebastian de la gomera  28.0916  -17.1133     25.20
#
#      Humidity  Cloudiness  Wind Speed Country        Date
# 49         86           0        2.57      US  1698172081
# 132        64           0        0.15      SD  1698172100
# 186        71           0        0.89      US  1698172113
# 195        74           0        1.51      GR  1698172115
# 328        38           0        0.89      US  1698171960
# 354        21           0        2.74      LY  1698172152
# 357        18           0        2.06      ZA  1698172153
# 400        38           0        1.01      PK  1698172163
# 424        85           0        2.57      US  1698172067
# 486        55           0        1.88      ZW  1698172183
# 508        33           0        1.52      MX  1698172188
# 536        57           0        2.57      ES  1698172194

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_ideal.loc[:,['City','Country','Lat','Lng','Humidity']]
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''
# Display sample data
hotel_df
# Out:
#                            City Country      Lat       Lng  Humidity  \
# 49            wailua homesteads      US  22.0669 -159.3780        86
# 132                  port sudan      SD  19.6175   37.2164        64
# 186                       linda      US  39.1277 -121.5508        71
# 195                       sitia      GR  35.2000   26.0986        74
# 328                   knoxville      US  35.9606  -83.9207        38
# 354                      waddan      LY  29.1614   16.1390        21
# 357                    upington      ZA -28.4478   21.2561        18
# 400                        jand      PK  33.4299   72.0193        38
# 424                       lihue      US  21.9789 -159.3672        85
# 486                    chipinge      ZW -20.1883   32.6236        55
# 508                 nuevo ideal      MX  24.8875 -105.0728        33
# 536  san sebastian de la gomera      ES  28.0916  -17.1133        57
#
#     Hotel Name
# 49
# 132
# 186
# 195
# 328
# 354
# 357
# 400
# 424
# 486
# 508
# 536

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "apiKey":geoapify_key,
    "categories":"accommodation.hotel"
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row['Lat']
    lon = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# port sudan - nearest hotel: Ranya Hotel
# linda - nearest hotel: Comfort Suites Marysville-Yuba City
# sitia - nearest hotel: Itanos Hotel
# knoxville - nearest hotel: Hilton Knoxville
# waddan - nearest hotel: No hotel found
# upington - nearest hotel: Die Eiland Holiday Ressort
# jand - nearest hotel: Rehman Hotel Jand
# lihue - nearest hotel: Kauai Palms
# chipinge - nearest hotel: No hotel found
# nuevo ideal - nearest hotel: No hotel found
# san sebastian de la gomera - nearest hotel: Hotel Villa Gomera
#                            City Country      Lat       Lng  Humidity  \
# 49            wailua homesteads      US  22.0669 -159.3780        86
# 132                  port sudan      SD  19.6175   37.2164        64
# 186                       linda      US  39.1277 -121.5508        71
# 195                       sitia      GR  35.2000   26.0986        74
# 328                   knoxville      US  35.9606  -83.9207        38
# 354                      waddan      LY  29.1614   16.1390        21
# 357                    upington      ZA -28.4478   21.2561        18
# 400                        jand      PK  33.4299   72.0193        38
# 424                       lihue      US  21.9789 -159.3672        85
# 486                    chipinge      ZW -20.1883   32.6236        55
# 508                 nuevo ideal      MX  24.8875 -105.0728        33
# 536  san sebastian de la gomera      ES  28.0916  -17.1133        57
#
#                               Hotel Name
# 49    Hilton Garden Inn Kauai Wailua Bay
# 132                          Ranya Hotel
# 186  Comfort Suites Marysville-Yuba City
# 195                         Itanos Hotel
# 328                     Hilton Knoxville
# 354                       No hotel found
# 357           Die Eiland Holiday Ressort
# 400                    Rehman Hotel Jand
# 424                          Kauai Palms
# 486                       No hotel found
# 508                       No hotel found
# 536                   Hotel Villa Gomera

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    alpha =0.8,
    color = 'City',
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
